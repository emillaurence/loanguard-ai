# %% [markdown]
# # 212 — Resolve Cross-References
#
# Merges per-document CSVs produced by notebook 211 and asks Claude Sonnet to resolve each cross-document reference to a known `section_id`.
#
# | Input | Output |
# |---|---|
# | `{regulation_id}_sections.csv` (one per doc) | `sections.csv` (merged) |
# | `{regulation_id}_requirements.csv` | `requirements.csv` (merged) |
# | `{regulation_id}_thresholds.csv` | `thresholds.csv` (merged) |
# | `{regulation_id}_references.csv` | `cross_references.csv` (resolved) |
#
# Re-runnable: yes.

# %%
import sys, os, json, time
import pandas as pd
import anthropic
from pathlib import Path
from dotenv import load_dotenv

project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

load_dotenv(project_root / '.env')

from src.document.utils import strip_fences, call_claude_stream_json

LAYER2_DIR       = project_root / 'data' / 'layer_2'
INTERMEDIATE_DIR = LAYER2_DIR / 'intermediate'

client     = anthropic.Anthropic(api_key=os.getenv('ANTHROPIC_API_KEY'))
MODEL      = 'claude-sonnet-4-6'
MAX_TOKENS = 8192   # raised from 4096 — 50 refs × 5 fields needs headroom
BATCH_SIZE = 25     # halved to reduce per-call output size

print(f'Intermediate dir: {INTERMEDIATE_DIR}')
# Out:
# Intermediate dir: /Users/emillaurencepastor/Documents/github/graphrag-finserv-compliance/data/layer_2/intermediate

# %% [markdown]
# ## Step 1 — Merge per-document CSVs

# %%
def load_and_merge(pattern: str) -> pd.DataFrame:
    files = sorted(INTERMEDIATE_DIR.glob(pattern))
    if not files:
        print(f'  No files matching {pattern}')
        return pd.DataFrame()
    dfs = [pd.read_csv(f) for f in files]
    print(f'  Merged {len(files)} file(s) matching {pattern}')
    return pd.concat(dfs, ignore_index=True)


sections_df     = load_and_merge('*_sections.csv')
requirements_df = load_and_merge('*_requirements.csv')
thresholds_df   = load_and_merge('*_thresholds.csv')
references_df   = load_and_merge('*_references.csv')

print(f'\nMerged totals:')
print(f'  sections:     {len(sections_df)}')
print(f'  requirements: {len(requirements_df)}')
print(f'  thresholds:   {len(thresholds_df)}')
print(f'  references:   {len(references_df)}')

# Write merged CSVs to LAYER2_DIR (used by subsequent notebooks)
sections_df.to_csv(LAYER2_DIR / 'sections.csv', index=False)
requirements_df.to_csv(LAYER2_DIR / 'requirements.csv', index=False)
thresholds_df.to_csv(LAYER2_DIR / 'thresholds.csv', index=False)
print('\nMerged CSVs written to data/layer_2/: sections.csv, requirements.csv, thresholds.csv')
# Out:
#   Merged 3 file(s) matching *_sections.csv
#   Merged 3 file(s) matching *_requirements.csv
#   Merged 3 file(s) matching *_thresholds.csv
#   Merged 3 file(s) matching *_references.csv
#
# Merged totals:
#   sections:     106
#   requirements: 226
#   thresholds:   248
#   references:   66
#
# Merged CSVs written to data/layer_2/: sections.csv, requirements.csv, thresholds.csv

# %% [markdown]
# ## Step 2 — Resolve cross-references via Claude

# %%
def resolve_batch(refs: list, all_section_ids: list) -> list:
    """Ask Claude to match a batch of references to known section_ids."""
    sections_list = '\n'.join(all_section_ids)
    refs_json     = json.dumps(refs, indent=2)

    system = (
        'You are resolving cross-document references in a regulatory knowledge graph. '
        'Match each reference to the best target section_id from the provided list. '
        'Return ONLY a valid JSON array, no markdown fences, no preamble.'
    )
    user_msg = (
        'Available section_ids:\n'
        + sections_list
        + '\n\nFor each reference below, find the best matching target section_id from the list above.'
        + ' If the referenced document is not in the list, set to_section_id to EXTERNAL.'
        + '\n\nReturn a JSON array where each element has:\n'
        + '  from_section_id   (string): the originating section\n'
        + '  to_section_id     (string): matched section_id, or EXTERNAL\n'
        + '  reference_type    (string): requires | elaborates | supplements | supersedes\n'
        + '  description       (string): brief description of the reference\n'
        + '  confidence        (string): high | medium | low\n'
        + '\nReferences to resolve:\n'
        + refs_json
    )

    return call_claude_stream_json(
        client,
        model=MODEL,
        max_tokens=MAX_TOKENS,
        system=system,
        messages=[{'role': 'user', 'content': user_msg}],
    )


all_section_ids = sections_df['section_id'].tolist() if not sections_df.empty else []
refs_list       = references_df.to_dict('records') if not references_df.empty else []

resolved_internal = []
external_refs     = []
batch_times       = []

if refs_list and all_section_ids:
    total_batches  = (len(refs_list) + BATCH_SIZE - 1) // BATCH_SIZE
    pipeline_start = time.perf_counter()

    for i in range(0, len(refs_list), BATCH_SIZE):
        batch     = refs_list[i:i + BATCH_SIZE]
        batch_num = i // BATCH_SIZE + 1
        print(f'Resolving batch {batch_num}/{total_batches}: {len(batch)} references...', end=' ', flush=True)
        t0       = time.perf_counter()
        resolved = resolve_batch(batch, all_section_ids)
        elapsed  = time.perf_counter() - t0
        batch_times.append(elapsed)
        print(f'{elapsed:.1f}s')
        for ref in resolved:
            if ref.get('to_section_id') == 'EXTERNAL':
                external_refs.append(ref)
            else:
                resolved_internal.append(ref)

    total_elapsed = time.perf_counter() - pipeline_start
    print(f'\nTotal API time: {total_elapsed:.1f}s (avg {sum(batch_times) / len(batch_times):.1f}s/batch)')
else:
    print('No references to resolve or no section_ids available.')

print(f'\nResolved: {len(resolved_internal)} internal cross-references')
print(f'External: {len(external_refs)} references to documents outside this set')
# Out:
# Resolving batch 1/3: 25 references... 25.7s
# Resolving batch 2/3: 25 references... 31.0s
# Resolving batch 3/3: 16 references... 11.9s
#
# Total API time: 68.5s (avg 22.8s/batch)
#
# Resolved: 25 internal cross-references
# External: 41 references to documents outside this set

# %% [markdown]
# ## Step 3 — Write cross_references.csv

# %%
COLUMNS = ['from_section_id', 'to_section_id', 'reference_type', 'description', 'confidence']

if resolved_internal:
    cross_df = pd.DataFrame(resolved_internal)

    # Drop any rows where the resolved section_id is not in the known set
    section_id_set = set(all_section_ids)
    valid_from = cross_df['from_section_id'].isin(section_id_set)
    valid_to   = cross_df['to_section_id'].isin(section_id_set)
    invalid    = cross_df[~(valid_from & valid_to)]
    if not invalid.empty:
        print(f'\u26a0  Dropping {len(invalid)} rows with unrecognised section_ids')
    cross_df = cross_df[valid_from & valid_to]

    # Ensure expected columns exist
    for col in COLUMNS:
        if col not in cross_df.columns:
            cross_df[col] = ''
    cross_df[COLUMNS].to_csv(LAYER2_DIR / 'cross_references.csv', index=False)
    print(f'Written cross_references.csv to data/layer_2/: {len(cross_df)} rows')
else:
    pd.DataFrame(columns=COLUMNS).to_csv(LAYER2_DIR / 'cross_references.csv', index=False)
    print('Written empty cross_references.csv to data/layer_2/ (no internal cross-references found)')
# Out:
# ⚠  Dropping 2 rows with unrecognised section_ids
# Written cross_references.csv to data/layer_2/: 23 rows

# %% [markdown]
# ## Step 4 — Summary

# %%
cross_path = LAYER2_DIR / 'cross_references.csv'
if cross_path.exists():
    cross_df = pd.read_csv(cross_path)

    if not cross_df.empty:
        def doc_prefix(sid: str) -> str:
            parts = str(sid).split('-')
            return '-'.join(parts[:2]) if len(parts) >= 2 else sid

        cross_df['from_doc'] = cross_df['from_section_id'].apply(doc_prefix)
        cross_df['to_doc']   = cross_df['to_section_id'].apply(doc_prefix)

        print('Cross-references by document pair:')
        print(cross_df.groupby(['from_doc', 'to_doc']).size().to_string())

        if 'confidence' in cross_df.columns:
            low_conf = cross_df[cross_df['confidence'] == 'low']
            if not low_conf.empty:
                print(f'\n\u26a0  {len(low_conf)} low-confidence matches — review these:')
                for _, row in low_conf.iterrows():
                    frm  = row['from_section_id']
                    to   = row['to_section_id']
                    desc = row.get('description', '')
                    print(f'  {frm} \u2192 {to}: {desc}')

if external_refs:
    print(f'\nExternal references (not ingested into graph):')
    for ref in external_refs:
        frm  = ref.get('from_section_id', '')
        desc = ref.get('description', '')
        print(f'  {frm}: {desc}')
# Out:
# Cross-references by document pair:
# from_doc  to_doc
# APG-223   APS-112     1
#           APS-220     3
# APS-112   APS-112    16
#           APS-220     2
# APS-220   APS-112     1
#
# ⚠  1 low-confidence matches — review these:
#   APS-112-ATT-B-S26-29 → APS-112-ATT-B-S26-29: Specialised lending exposures with an issue-specific external credit rating must use Table 10 risk weights.
#
# External references (not ingested into graph):
#   APG-223-S1: APG 223 should be read alongside CPS 220 Risk Management, which sets the overarching risk management framework requirements within which residential mortgage lending must be managed.
#   APG-223-S1: CPG 220 provides additional guidance on risk management practices that is complementary to the residential mortgage-specific guidance in APG 223.
#   APG-223-S1: CPS 510 Governance sets requirements for Board-approved remuneration policies aligned with prudent risk-taking, which apply to residential mortgage lending personnel including broker arrangements.
#   APG-223-S3: Consistent with CPS 220, ADIs must have policies and procedures for identifying, measuring, monitoring and controlling material risks in the residential mortgage portfolio, with comprehensive independent review at least every three years.
#   APG-223-S3: CPS 510 requires the remuneration policy to apply to responsible persons, risk and financial control personnel and all other persons whose activities may affect the financial soundness of the institution, including those involved in residential mortgage lending.
#   APG-223-S3: CPG 235 provides guidance on managing data risk relevant to the management information system requirements for residential mortgage lending portfolios.
#   APG-223-S4: Consistent with CPS 231, an ADI retains both risk and responsibility for material outsourced functions including origination and ongoing management of residential mortgage lending by third parties.
#   APG-223-S7: The definition of when a residential mortgage loan is in default, triggering full revaluation requirements, is referenced to paragraph 76 of Attachment A of APS 113.
#   APG-223-S8: APS 110 requires ADIs to conduct enterprise-wide stress testing as part of internal capital planning, which is the foundation upon which residential mortgage portfolio stress testing sits.
#   APG-223-S8: CPG 110 provides guidance on stress testing and scenario analysis approaches used in the ICAAP, supplementing the residential mortgage-specific stress testing expectations in APG 223.
#   APG-223-S2: APRA had regard to the FSB Principles for Sound Residential Mortgage Underwriting Practices in developing APG 223, and would expect ADIs lending outside Australia to apply similarly conservative standards.
#   APS-112-S2: This Prudential Standard is made under section 11AF of the Banking Act 1959.
#   APS-112-S6: Assets required to be deducted from capital under APS 111 are excluded from the scope of APS 112.
#   APS-112-S6: Securitisation exposures subject to APS 120 are excluded from APS 112 scope, except funding-only or synthetic securitisations where underlying pool exposures must be included in the credit risk RWA calculation.
#   APS-112-S6: Liabilities of a covered bond special purpose vehicle to an issuing ADI as specified in APS 121 are excluded from the scope of APS 112.
#   APS-112-S6: Items subject to capital requirements under APS 116 that do not have counterparty credit risk under APS 180 are excluded from APS 112 scope.
#   APS-112-S6: Items subject to APS 116 capital requirements but lacking counterparty credit risk under APS 180 are excluded from APS 112. APS 180 equivalent rules are used for New Zealand regulated subsidiaries.
#   APS-112-S7: Terms defined in APS 001 Definitions appear in bold on first use in this Standard.
#   APS-112-S7: Related-party exposure is defined by reference to a related entity as defined in APS 222, and is classified according to asset class definitions in Attachment B.
#   APS-112-S8: For liquid assets at amortised cost, an ADI may adjust exposures for deductions from CET1 to reflect unrealised fair value losses at a portfolio level as allowed under paragraph 41 of Attachment D to APS 111.
#   APS-112-S9: For significant financial institution ADIs, EAD for OTC and exchange-traded derivative transactions or long-settlement transactions must be determined using APS 180.
#   APS-112-ATT-B-S33: Subordinated debt not required to be deducted from regulatory capital under APS 111 must be risk-weighted at 150 per cent.
#   APS-112-ATT-B-S34-38: Equity exposures not required to be deducted from regulatory capital under APS 111 must be risk-weighted at 250% or 400%; equity in banking or insurance subsidiaries is subject to the deduction threshold in Attachment D to APS 111.
#   APS-112-ATT-G: Senior securitisation exposures (as defined in APS 120) with a credit rating grade of one are eligible collateral under the simple approach; resecuritisation exposures (as defined in APS 120) are not eligible.
#   APS-112-ATT-G: For OTC derivatives, EAD is calculated using the adjusted CEM referenced in Attachment E to APS 180; qualifying central counterparties as defined in APS 180 are core market participants for SFT risk-weight purposes.
#   APS-112-ATT-G-COLL-MATURITY: Table 23 footnote references APS 120 for the meaning of securitisation exposure as used in the supervisory haircuts table.
#   APS-112-ATT-I: A guarantee with a materiality threshold must be deducted from Common Equity Tier 1 Capital in accordance with APS 111.
#   APS-112-ATT-J-PURCHASED: Where an ADI buys credit protection through a credit derivative forming part of a synthetic securitisation, the requirements detailed in APS 120 apply.
#   APS-112-ATT-J-PROVIDERS: Materiality thresholds in credit derivatives treated as retained first-loss positions must be deducted from Common Equity Tier 1 Capital in accordance with APS 111.
#   APS-112-ATT-J-PARTIAL: Where partial credit derivative coverage creates a seniority difference between protected and unprotected portions, the arrangement is treated as a synthetic securitisation subject to APS 120.
#   APS-220-S3: The Standard does not apply to exposures securitised or transferred into securitisation vehicles meeting APRA's operational requirements for regulatory capital relief under APS 120.
#   APS-220-S4: Terms defined in APS 001 appear in bold on first use in this Prudential Standard.
#   APS-220-S8: An ADI need not have a standalone credit risk appetite statement or management strategy where they form part of the overall risk appetite statement or risk management strategy required under CPS 220.
#   APS-220-S9: ADIs outsourcing aspects of credit risk management including origination, assessment and approval must comply with CPS 231 for those outsourced functions.
#   APS-220-S10: For large exposures, ADIs must also have regard to APS 221 Large Exposures.
#   APS-220-S10: For associations with related entities, ADIs must also have regard to APS 222 Associations with Related Entities.
#   APS-220-S13: Board requirements for foreign ADIs must be read subject to CPS 510, which requires a senior officer outside Australia with delegated authority.
#   APS-220-S14: In addition to CPS 220 requirements, ADIs must develop and implement policies to ensure adequate credit portfolio diversification including prudent limits on higher-risk borrowers and sectors.
#   APS-220-S14: Credit portfolio diversification requirements are in addition to the requirements in APS 221.
#   APS-220-S14: Credit portfolio diversification requirements are in addition to the requirements in APS 222.
#   APS-220-S20: ADIs must calculate derivative transaction exposures to counterparties for non-performing classification purposes under the standardised approach or adjusted current exposure method prescribed in APS 180.
